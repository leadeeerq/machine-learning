# %% [markdown]
# <a href="https://colab.research.google.com/github/leadeeerq/machine-learning/blob/main/2_ML27_K_%C5%9Brednich.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import plotly.express as px
import matplotlib.pyplot as plt

# %% [markdown]
# #Generowanie danych

# %%
from sklearn.datasets import make_blobs

data = make_blobs(n_samples=1000, centers=None, cluster_std=1.0, center_box=(-4.0, 4.0), random_state=42)[0]
df = pd.DataFrame(data, columns=['x1', 'x2'])
df.head()
# Out:
#          x1        x2
# 0 -2.468563 -3.010949
# 1 -2.009756 -2.452751
# 2  2.414278  0.865273
# 3 -1.463040  2.755870
# 4 -1.263270  2.102571

# %% [markdown]
# #Wizualizacja danych

# %%
# px.scatter(df, 'x1', 'x2', width=950, height=500, title='Klasteryzacja - algorytm K-średnich')
plt.scatter(df['x1'], df['x2'])
plt.rcParams["figure.figsize"] = (20,3)
plt.title('Klasteryzacja - algorytm K-średnich')
# Out:
# Text(0.5, 1.0, 'Klasteryzacja - algorytm K-średnich')

# %% [markdown]
# #Algorytm K-średnich

# %%
from sklearn.cluster import KMeans

n_clusters = 6

kmeans = KMeans(n_clusters= n_clusters)
kmeans.fit(data)
# Out:
# KMeans(n_clusters=6)

# %%
y_kmeans = kmeans.predict(data)
y_kmeans[:10]
# Out:
# array([0, 0, 4, 3, 3, 0, 1, 1, 1, 4], dtype=int32)

# %%
df['y_kmeans'] = y_kmeans
df.head()
# Out:
#          x1        x2  y_kmeans
# 0 -2.468563 -3.010949         0
# 1 -2.009756 -2.452751         0
# 2  2.414278  0.865273         4
# 3 -1.463040  2.755870         3
# 4 -1.263270  2.102571         3

# %% [markdown]
# #Wizualizacja

# %%
df['y_kmeans'][2]
# Out:
# 4

# %%
px.scatter(df, 'x1', 'x2', 'y_kmeans', width=950, height=500, title=f'Algorytm K-średnich - {n_clusters} klastrów')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ![image.png](data:image/png;base64,...)
